# %% [markdown]
# Prakhar Jain

# %% [markdown]
# The objective of this project is the analysis of multiple cryptocurrencies to get an overview of the cryptocurrency market. Then the statistical analysis of bitcoin historical prices carried out with the help of Seaborn and Matplotlib library of Python

# %%
# Importing relevant libraries
import pandas as pd
import numpy as np
import seaborn as sea
import matplotlib.pyplot as plt

# %%
# Fetching data from an excel file
data = pd.read_excel('1000_crypto_DA.xlsx')

# %%
# Showing data
data
# Out:
#        Coin_name      Price($)  Change_1h(%)  Change_24h(%)  Change_7d(%)  \
# 0        Bitcoin  17831.080000           0.1            3.8           4.4
# 1       Ethereum   1324.940000           0.1            4.5           4.2
# 2         Tether      1.000000           0.1            0.2           0.1
# 3       USD Coin      1.000000           0.1            0.2           0.2
# 4            BNB    275.330000          -0.2            3.3          -5.1
# ..           ...           ...           ...            ...           ...
# 995    Town Star      0.019063          -0.5           -0.1          -1.9
# 996     Validity      1.360000           0.0            2.3           2.0
# 997       Banano      0.004554           0.2            2.9          11.6
# 998        Cirus      0.102925          -0.2           -0.2          -7.1
# 999  Waltonchain      0.218184           0.5            3.2          -5.1
#
#         Volume($)  Market cap($)
# 0    2.730389e+10   342697854808
# ...

# %%
# Showing the name of columns, their data types, and range
print(data.info(),data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Coin_name      1000 non-null   object
#  1   Price($)       1000 non-null   float64
#  2   Change_1h(%)   974 non-null    float64
#  3   Change_24h(%)  978 non-null    float64
#  4   Change_7d(%)   978 non-null    float64
#  5   Volume($)      978 non-null    float64
#  6   Market cap($)  1000 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 54.8+ KB
# None Index(['Coin_name', 'Price($)', 'Change_1h(%)', 'Change_24h(%)',
#        'Change_7d(%)', 'Volume($)', 'Market cap($)'],
#       dtype='object')

# %%
# Reindexing to columns
data.columns=['Coin_name', 'Price($)', 'Change_1h(%)', 'Change_24h(%)', 'Change_7d(%)', 'Volume($)', 'Market cap($)']
print(data.info(),data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Coin_name      1000 non-null   object
#  1   Price($)       1000 non-null   float64
#  2   Change_1h(%)   974 non-null    float64
#  3   Change_24h(%)  978 non-null    float64
#  4   Change_7d(%)   978 non-null    float64
#  5   Volume($)      978 non-null    float64
#  6   Market cap($)  1000 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 54.8+ KB
# None Index(['Coin_name', 'Price($)', 'Change_1h(%)', 'Change_24h(%)',
#        'Change_7d(%)', 'Volume($)', 'Market cap($)'],
#       dtype='object')

# %%
# Rows with null values
print(data[data.isnull().T.any()])
# Out:
#                           Coin_name      Price($)  Change_1h(%)  \
# 204                           cUSDT  1.099494e-02           NaN
# 277                    MaidSafeCoin  1.217130e-01           NaN
# 291  Ankr Reward-Bearing Staked ETH  1.318270e+03           NaN
# 362                 BoringDAO [OLD]  3.090000e+01           NaN
# 421             MrWeb Finance [OLD]  1.915638e-04           NaN
# 473                         Rootkit  1.097300e+03           NaN
# 497                       BOX Token  5.005577e-03           NaN
# 556                           Inari  1.230504e-04           NaN
# 603               Sport and Leisure  9.145976e-02           NaN
# 655         Golden Society Token V2  9.290000e+00           NaN
# 683                      Ultiledger  8.801060e-03           NaN
# 759                veCRV-DAO yVault  6.355820e-01           NaN
# 763                     QANplatform  5.634154e-03           NaN
# 817                       AurusDeFi  3.210000e+00           NaN
# ...

# %%
# Dropping all the rows with null values
data=data.dropna()
#Printing the new data
data
# Out:
#        Coin_name      Price($)  Change_1h(%)  Change_24h(%)  Change_7d(%)  \
# 0        Bitcoin  17831.080000           0.1            3.8           4.4
# 1       Ethereum   1324.940000           0.1            4.5           4.2
# 2         Tether      1.000000           0.1            0.2           0.1
# 3       USD Coin      1.000000           0.1            0.2           0.2
# 4            BNB    275.330000          -0.2            3.3          -5.1
# ..           ...           ...           ...            ...           ...
# 995    Town Star      0.019063          -0.5           -0.1          -1.9
# 996     Validity      1.360000           0.0            2.3           2.0
# 997       Banano      0.004554           0.2            2.9          11.6
# 998        Cirus      0.102925          -0.2           -0.2          -7.1
# 999  Waltonchain      0.218184           0.5            3.2          -5.1
#
#         Volume($)  Market cap($)
# 0    2.730389e+10   342697854808
# ...

# %%
# Getting the information of Columns
print(data.info(),data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 974 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Coin_name      974 non-null    object
#  1   Price($)       974 non-null    float64
#  2   Change_1h(%)   974 non-null    float64
#  3   Change_24h(%)  974 non-null    float64
#  4   Change_7d(%)   974 non-null    float64
#  5   Volume($)      974 non-null    float64
#  6   Market cap($)  974 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 60.9+ KB
# None Index(['Coin_name', 'Price($)', 'Change_1h(%)', 'Change_24h(%)',
#        'Change_7d(%)', 'Volume($)', 'Market cap($)'],
#       dtype='object')

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# Now the data is clean, so now we can perform Data Analysis on it.

# %%
# As there are a lot of decimal places in some rows, so setting the maximum character 2 after decimals
pd.set_option("display.precision", 2)
pd.set_option("display.float_format", "{:.2f}".format)

# %%
#checking if the data is changed after changing decimal places
data.head()
# Out:
#   Coin_name  Price($)  Change_1h(%)  Change_24h(%)  Change_7d(%)  \
# 0   Bitcoin  17831.08          0.10           3.80          4.40
# 1  Ethereum   1324.94          0.10           4.50          4.20
# 2    Tether      1.00          0.10           0.20          0.10
# 3  USD Coin      1.00          0.10           0.20          0.20
# 4       BNB    275.33         -0.20           3.30         -5.10
#
#        Volume($)  Market cap($)
# 0 27303889807.00   342697854808
# 1  8300780394.00   159561625262
# 2 38287826880.00    66024352936
# 3  3545735029.00    45066082506
# 4  1804721374.00    44902863845

# %%
# Finding the highest and lowest from all the CryptoCurrencies according to their Market Capitalization,
# 1 hour change, 24 hour change, 7 day change, and Volume

maxMarketCap=data.loc[data['Market cap($)']==data['Market cap($)'].max(),['Coin_name','Market cap($)']]
minMarketCap=data.loc[data['Market cap($)']==data['Market cap($)'].min(),['Coin_name','Market cap($)']]
highest_gainer_1hour = data.loc[data['Change_1h(%)']==data['Change_1h(%)'].max(),['Coin_name', 'Change_1h(%)']]
biggest_loser_1hour = data.loc[data['Change_1h(%)']==data['Change_1h(%)'].min(),['Coin_name', 'Change_1h(%)']]
highest_gainer_24hour = data.loc[data['Change_24h(%)']==data['Change_24h(%)'].max(),['Coin_name', 'Change_24h(%)']]
biggest_loser_24hour = data.loc[data['Change_24h(%)']==data['Change_24h(%)'].min(),['Coin_name', 'Change_24h(%)']]
highest_gainer_7d = data.loc[data['Change_7d(%)']==data['Change_7d(%)'].max(),['Coin_name', 'Change_7d(%)']]
biggest_loser_7d = data.loc[data['Change_7d(%)']==data['Change_7d(%)'].min(),['Coin_name', 'Change_7d(%)']]
crypto_largest_volume = data.loc[data['Volume($)']==data['Volume($)'].max(),['Coin_name', 'Volume($)']]
crypto_smallest_volume = data.loc[data['Volume($)']==data['Volume($)'].min(),['Coin_name', 'Volume($)']]
print('Currency with highest Market Cap', maxMarketCap, 'Currency with Lowest Market Cap', minMarketCap,
      'Highest gainer of 1 hour', highest_gainer_1hour, 'Biggest loser of 1 hour', biggest_loser_1hour, 
      'Highest gainer of 24 hour', highest_gainer_24hour, 'Biggest loser of 24 hour', biggest_loser_24hour,
      'Highest gainer of 7 days', highest_gainer_7d, 'Biggest loser of 24 hour', biggest_loser_7d,
      'Crypto with highest volume(24 hours)', crypto_largest_volume, 'Crypto with lowest volume(24 hours)', crypto_smallest_volume,
      sep='\n')
# Out:
# Currency with highest Market Cap
#   Coin_name  Market cap($)
# 0   Bitcoin   342697854808
# Currency with Lowest Market Cap
#        Coin_name  Market cap($)
# 999  Waltonchain        6364730
# Highest gainer of 1 hour
#     Coin_name  Change_1h(%)
# 460    Cortex         17.50
# Biggest loser of 1 hour
#         Coin_name  Change_1h(%)
# 275  Neutrino USD        -12.90
# Highest gainer of 24 hour
#       Coin_name  Change_24h(%)
# 628  Aave [OLD]         949.10
# Biggest loser of 24 hour
#         Coin_name  Change_24h(%)
# 994  BTU Protocol         -59.60
# Highest gainer of 7 days
#     Coin_name  Change_7d(%)
# 872    HEdpAY        147.70
# Biggest loser of 24 hour
#     Coin_name  Change_7d(%)
# 810    ZigZag        -67.60
# Crypto with highest volume(24 hours)
#   Coin_name      Volume($)
# 2    Tether 38287826880.00
# Crypto with lowest volume(24 hours)
#           Coin_name  Volume($)
# 396   Instadapp ETH       0.00
# 758   Pundi X [OLD]       0.00
# ...

# %%
# Statistical Measures of all the columns with data type float and integer
data.describe()
# Out:
#        Price($)  Change_1h(%)  Change_24h(%)  Change_7d(%)      Volume($)  \
# count    974.00        974.00         974.00        974.00         974.00
# mean     178.60          0.10           4.06         -0.53   106322633.94
# std     1660.33          1.35          31.10         13.94  1574256475.44
# min        0.00        -12.90         -59.60        -67.60           0.00
# 25%        0.03         -0.20           0.70         -5.70      154421.75
# 50%        0.21          0.10           3.00         -1.40      902464.50
# 75%        1.15          0.30           4.70          2.10     4777397.25
# max    26832.87         17.50         949.10        147.70 38287826880.00
#
#         Market cap($)
# count          974.00
# mean     930383485.00
# std    12497694749.16
# min        6364730.00
# 25%       13837613.25
# 50%       32442144.00
# 75%       89593317.00
# max   342697854808.00

# %%
# Number of crypto currencies which gained between a particular range

data['Change_24h(%)']=(data['Change_24h(%)'])
frequencyData=pd.cut(data['Change_24h(%)'],list(range(1,10,1)),right=False)
AvePriceFrequency=frequencyData.value_counts(sort=False)
print('Frequency',AvePriceFrequency,'Frequency Distribution',frequencyData.value_counts(sort=False,normalize='True'),sep='\n')
# Out:
# Frequency
# [1, 2)     95
# [2, 3)    125
# [3, 4)    137
# [4, 5)    126
# [5, 6)     73
# [6, 7)     37
# [7, 8)     34
# [8, 9)     14
# Name: Change_24h(%), dtype: int64
# Frequency Distribution
# [1, 2)   0.15
# [2, 3)   0.20
# [3, 4)   0.21
# [4, 5)   0.20
# [5, 6)   0.11
# [6, 7)   0.06
# [7, 8)   0.05
# [8, 9)   0.02
# Name: Change_24h(%), dtype: float64
# C:\Users\PRAKHAR\AppData\Local\Temp\ipykernel_2988\2776961994.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Change_24h(%)']=(data['Change_24h(%)'])

# %%
# Crypto Currencies which have price more than $500
print(data[data["Price($)"]>=500].count())
data[data["Price($)"]>=500]
# Out:
# Coin_name        25
# Price($)         25
# Change_1h(%)     25
# Change_24h(%)    25
# Change_7d(%)     25
# Volume($)        25
# Market cap($)    25
# dtype: int64
#                              Coin_name  Price($)  Change_1h(%)  Change_24h(%)  \
# 0                              Bitcoin  17831.08          0.10           3.80
# 1                             Ethereum   1324.94          0.10           4.50
# 10                   Lido Staked Ether   1310.13          0.00           4.40
# 21                     Wrapped Bitcoin  17811.75          0.00           3.70
# 71                               Maker    606.07          0.20           4.10
# 76                            PAX Gold   1818.09          0.10           2.10
# 84                         Tether Gold   1754.10         -0.10           1.80
# 133                    Rocket Pool ETH   1422.83          0.00           4.50
# 134                          Huobi BTC  17837.05          0.20           4.50
# ...

# %%
# Calculating the mean price of all crypto currencies which have price more than $1500
data[data["Price($)"]>=1500]["Price($)"].mean()
# Out:
# 12745.5

# %%
# Top 10 Cryptocurrencies by Market Capitalization
top_10_marketcap = data.nlargest(10, "Market cap($)")
top_10_marketcap
# Out:
#      Coin_name  Price($)  Change_1h(%)  Change_24h(%)  Change_7d(%)  \
# 0      Bitcoin  17831.08          0.10           3.80          4.40
# 1     Ethereum   1324.94          0.10           4.50          4.20
# 2       Tether      1.00          0.10           0.20          0.10
# 3     USD Coin      1.00          0.10           0.20          0.20
# 4          BNB    275.33         -0.20           3.30         -5.10
# 5          XRP      0.39          0.20           2.20         -0.20
# 6  Binance USD      1.00          0.00           0.10          0.10
# 7     Dogecoin      0.09          0.10           3.20         -9.00
# 8      Cardano      0.31          0.00           2.60         -2.80
# 9      Polygon      0.92          0.20           3.90          0.50
#
#        Volume($)  Market cap($)
# 0 27303889807.00   342697854808
# 1  8300780394.00   159561625262
# 2 38287826880.00    66024352936
# 3  3545735029.00    45066082506
# 4  1804721374.00    44902863845
# ...

# %%
#Creating a list of Cryptocurrencies except the top 10 crypto currencies by market capitalization
except_top_10_marketcap = ~data.isin(top_10_marketcap)

# %%
# Sum of Market Capitalization of all the Cryptocurrencies except the top 10 crypto currencies by market capitalization
sum_excep_top_10 = data[except_top_10_marketcap]['Market cap($)'].sum()
sum_excep_top_10
# Out:
# 177754396326.0

# %%
# Sum of Market Capitalization all Crypto Currencies 
data['Market cap($)'].sum()
# Out:
# 906193514389

# %%
# Making a pie chart to define that only top 10 Cryptocurrencies by Market Capitalization make up around 80% of 
# Market Capitalization of all the Cryptocurrencies

labels = ['Top 10', 'Remaining all cryptos']
sizes = [top_10_marketcap['Market cap($)'].sum(), sum_excep_top_10]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
# Top 10 gainers in 7 days
top_gainers = data.nlargest(10, 'Change_7d(%)')
top_gainers
# Out:
#                                     Coin_name  Price($)  Change_1h(%)  \
# 872                                    HEdpAY      0.14          2.10
# 467                            Metars Genesis      2.01          0.40
# 334                                RAMP [OLD]      0.15         -1.00
# 344                                   LeverFi      0.00         -3.30
# 460                                    Cortex      0.18         17.50
# 604                                  THORSwap      0.23          0.80
# 623                                   Freeway      0.00         -0.50
# 978                           Rari Governance      0.62          0.10
# 679  Argentine Football Association Fan Token      4.85         -4.30
# 552                         Revolution Populi      0.02         -0.90
#
#      Change_24h(%)  Change_7d(%)   Volume($)  Market cap($)
# 872          89.00        147.70     1748.64        9045044
# 467          68.50        127.20   544487.00       35348177
# ...

# %%
# Top 10 losers in 7 days
top_losers = data.nsmallest(10, 'Change_7d(%)')
top_losers
# Out:
#      Coin_name  Price($)  Change_1h(%)  Change_24h(%)  Change_7d(%)  \
# 810     ZigZag      0.73        -10.20         -21.20        -67.60
# 971   Mycelium      0.01         -7.60         -31.20        -56.30
# 859     VICUNA      0.07         -0.10           0.00        -54.90
# 225  Coinmetro      0.34         -0.10           4.20        -46.20
# 954       Skeb      0.01          0.10          -3.30        -40.30
# 565       Hxro      0.06         -0.30          -4.50        -36.30
# 527     INSTAR      0.02          0.10         -53.60        -35.40
# 933      WeWay      0.01         -2.70         -13.10        -32.80
# 993     Sipher      0.07          0.10         -11.80        -32.00
# 214      WEMIX      0.44         -0.70           9.50        -31.40
#
#      Volume($)  Market cap($)
# 810  171290.00       10975261
# 971  158849.00        7159948
# 859   36140.04        9304994
# 225    2019.05      102269800
# 954  152396.00        7406249
# 565   17726.45       25036898
# ...

# %%
#Getting all the cryptos which have volume more than average volume of 1000 Cryptos
avg= data["Volume($)"].mean()
print(data[data["Volume($)"]>avg].count())
data[data["Volume($)"]>avg]
# Out:
# Coin_name        35
# Price($)         35
# Change_1h(%)     35
# Change_24h(%)    35
# Change_7d(%)     35
# Volume($)        35
# Market cap($)    35
# dtype: int64
#             Coin_name  Price($)  Change_1h(%)  Change_24h(%)  Change_7d(%)  \
# 0             Bitcoin  17831.08          0.10           3.80          4.40
# 1            Ethereum   1324.94          0.10           4.50          4.20
# 2              Tether      1.00          0.10           0.20          0.10
# 3            USD Coin      1.00          0.10           0.20          0.20
# 4                 BNB    275.33         -0.20           3.30         -5.10
# 5                 XRP      0.39          0.20           2.20         -0.20
# 6         Binance USD      1.00          0.00           0.10          0.10
# 7            Dogecoin      0.09          0.10           3.20         -9.00
# 8             Cardano      0.31          0.00           2.60         -2.80
# ...

# %%
# Number of Crypto currencies which lost in 24 hours
data[data["Change_24h(%)"]<0].count()
# Out:
# Coin_name        154
# Price($)         154
# Change_1h(%)     154
# Change_24h(%)    154
# Change_7d(%)     154
# Volume($)        154
# Market cap($)    154
# dtype: int64

# %%
#Number of crypto currencies which gain in 24 hours
data[data["Change_24h(%)"]>0].count()
# Out:
# Coin_name        803
# Price($)         803
# Change_1h(%)     803
# Change_24h(%)    803
# Change_7d(%)     803
# Volume($)        803
# Market cap($)    803
# dtype: int64

# %%
# Creating a Distribution graph of Percentage change in 7 Days of Crypto Currencies
sea.displot(data['Change_7d(%)'], kde=False) 
plt.xlabel('Percentage Change')
plt.title('Distribution of Percentage Change in 7 Days')
plt.ylabel('Number of CryptoCurrencies')
# Out:
# Text(5.069444444444445, 0.5, 'Number of CryptoCurrencies')

# %%
# Create a range object
Change_24h_range = range(0, 10, 1)

# Group the data by price range
Change_24h_group = data.groupby(pd.cut(data['Change_24h(%)'], Change_24h_range))

# Print the groups
print(Change_24h_group.groups)
# Out:
# {(0, 1]: [2, 3, 6, 15, 40, 52, 54, 56, 78, 126, 136, 140, 185, 198, 201, 202, 208, 229, 237, 255, 264, 280, 336, 337, 343, 349, 370, 371, 378, 383, 384, 385, 416, 424, 437, 439, 452, 453, 461, 464, 471, 472, 479, 486, 499, 503, 520, 532, 536, 539, 545, 546, 548, 550, 554, 558, 561, 589, 592, 595, 602, 624, 646, 669, 674, 678, 680, 686, 700, 704, 705, 706, 709, 710, 724, 728, 744, 747, 749, 751, 757, 788, 793, 798, 805, 809, 812, 833, 840, 847, 864, 917, 922, 940, 949, 951, 952, 966, 968, 991], (1, 2]: [25, 27, 33, 59, 63, 67, 70, 84, 95, 101, 117, 151, 153, 156, 159, 180, 182, 196, 197, 222, 232, 245, 247, 252, 254, 282, 289, 295, 297, 306, 309, 324, 333, 356, 358, 366, 369, 374, 386, 393, 403, 413, 441, 447, 451, 475, 484, 494, 508, 513, 514, 555, 564, 566, 578, 584, 599, 605, 606, 609, 623, 625, 632, 644, 650, 666, 671, 692, 693, 703, 707, 714, 729, 734, 737, 740, 765, 770, 794, 795, 800, 820, 826, 832, 862, 886, 892, 916, 918, 920, 943, 944, 958, 974, 975, 977, 980], (2, 3]: [5, 8
# ...

# %%
# Making a variable to store the number of groups created above
group_count = Change_24h_group.size()

# %%
# Displaying groups with number of crypto currencies in it
group_count
# Out:
# Change_24h(%)
# (0, 1]    100
# (1, 2]     97
# (2, 3]    135
# (3, 4]    139
# (4, 5]    108
# (5, 6]     77
# (6, 7]     32
# (7, 8]     32
# (8, 9]     14
# dtype: int64

# %%
# Importing relevant libraries for Regression analysis
import statsmodels.api as sm 

#Study the linear relationship between market cap and price where is the independent variable
reg=sm.OLS(data['Market cap($)'],data['Price($)']).fit()
print(reg.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:          Market cap($)   R-squared (uncentered):              -25207.883
# Model:                            OLS   Adj. R-squared (uncentered):         -25233.791
# Method:                 Least Squares   F-statistic:                             -973.0
# Date:                Fri, 16 Dec 2022   Prob (F-statistic):                        1.00
# Time:                        02:34:32   Log-Likelihood:                         -23978.
# No. Observations:                 974   AIC:                                  4.796e+04
# Df Residuals:                     973   BIC:                                  4.796e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#Creating a scatterplot for regression of Market Capitalization and Price
sea.regplot(x="Market cap($)", y="Price($)", data=data)
# Out:
# <AxesSubplot: xlabel='Market cap($)', ylabel='Price($)'>

# %% [markdown]
# Bitcoin has the largest market value. So, we want to make a separate analysis. We captured financial data for nearly two months. In general, the market value of bitcoin fluctuated greatly in a short time. The maximum value was reached on November 6, and the minimum value was reached on November 10. The lowest price and the highest price appeared in November. From the scatter chart, the market value is positively correlated with the stock price. From the broken line chart, the market value and price change trends are the same. We did two sets of regression analysis. First, return the market value and price. Second, stock price autoregression. The regression results of both groups showed a strong correlation.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
x=pd.read_csv('Bitcoin USD (Historical Data)HistoricalData12.16-0..43.csv')
print(x.info(),x.columns)
x=x[['Date', 'Market Cap', 'Volume', 'Open', 'Close']]
print(x[x.isnull().T.any()]) #test whether has N/A
print(x)
x=x.dropna()  #delete the row having N/A (the first row)
print(x.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  60 non-null     int64
#  1   Date        60 non-null     object
#  2   Market Cap  60 non-null     float64
#  3   Volume      60 non-null     float64
#  4   Open        60 non-null     float64
#  5   Close       59 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.9+ KB
# None Index(['Unnamed: 0', 'Date', 'Market Cap', 'Volume', 'Open', 'Close'], dtype='object')
#          Date      Market Cap         Volume     Open  Close
# 0  2022-11-30 316170903326.00 24663035431.00 16441.98    NaN
#           Date      Market Cap          Volume     Open    Close
# 0   2022-11-30 316170903326.00  24663035431.00 16441.98      NaN
# 1   2022-11-29 311810991501.00  24566056814.00 16222.21 16441.98
# 2   2022-11-28 316487666895.00  16551822516.00 16459.15 16222.21
# ...

# %%
print("This document contains Bitcoin's daily price data from {} to {},totalling {} numbers of data".format(x.iloc[-1,0],x.iloc[0,0],len(x['Open'])))
# Out:
# This document contains Bitcoin's daily price data from 2022-10-02 to 2022-11-29,totalling 59 numbers of data

# %%
print(x.info(),x.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 1 to 59
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        59 non-null     object
#  1   Market Cap  59 non-null     float64
#  2   Volume      59 non-null     float64
#  3   Open        59 non-null     float64
#  4   Close       59 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.8+ KB
# None Index(['Date', 'Market Cap', 'Volume', 'Open', 'Close'], dtype='object')

# %%
maxMarketCap=x.loc[x['Market Cap']==x['Market Cap'].max(),['Date','Market Cap']]
minMarketCap=x.loc[x['Market Cap']==x['Market Cap'].min(),['Date','Market Cap']]
print('maxMarketCap',maxMarketCap,'minMarketCap',minMarketCap,sep='\n')
# Out:
# maxMarketCap
#           Date      Market Cap
# 24  2022-11-06 408892506459.00
# minMarketCap
#           Date      Market Cap
# 20  2022-11-10 301963847694.00

# %%
x['AvePrice']=(x['Open']+x['Close'])/2
maxAvePrice=x.loc[x['AvePrice']==x['AvePrice'].max(),['Date','AvePrice']]
minAvePrice=x.loc[x['AvePrice']==x['AvePrice'].min(),['Date','AvePrice']]
print('maxAvePrice',maxAvePrice,'minAvePrice',minAvePrice,sep='\n')
# Out:
# maxAvePrice
#           Date  AvePrice
# 25  2022-11-05  21216.50
# minAvePrice
#          Date  AvePrice
# 8  2022-11-22  15992.99

# %%
frequencyData=pd.cut(x['AvePrice'],list(range(15500,21501,1000)),right=False)
AvePriceFrequency=frequencyData.value_counts(sort=False)
print('Frequency',AvePriceFrequency,'Frequency Distribution',frequencyData.value_counts(sort=False,normalize='True'),sep='\n')
#Average price interval distribution, frequency distribution and positive probability distribution
# Out:
# Frequency
# [15500, 16500)     8
# [16500, 17500)    13
# [17500, 18500)     0
# [18500, 19500)    19
# [19500, 20500)    11
# [20500, 21500)     8
# Name: AvePrice, dtype: int64
# Frequency Distribution
# [15500, 16500)   0.14
# [16500, 17500)   0.22
# [17500, 18500)   0.00
# [18500, 19500)   0.32
# [19500, 20500)   0.19
# [20500, 21500)   0.14
# Name: AvePrice, dtype: float64

# %%
# %matplotlib inline
x['AvePrice'].plot.density() #Distribution density map
y=seaborn.distplot(x['AvePrice'])
plt.xlabel('price')
plt.title('Distribution Plot for Average Price')
y=seaborn.displot(x['AvePrice'])
plt.xlabel('price')
plt.title('Distribution Plot for Average Price')
x['AvePrice'].describe()
# Out:
# C:\Users\PRAKHAR\AppData\Local\Temp\ipykernel_2988\898703366.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   y=seaborn.distplot(x['AvePrice'])
# count      59.00
# mean    18679.12
# std      1655.10
# min     15992.99
# 25%     16711.28
# 50%     19241.14
# 75%     20019.15
# max     21216.50
# Name: AvePrice, dtype: float64

# %%
import matplotlib.ticker as ticker
seaborn.catplot(x='Market Cap',y='AvePrice',data=x)
plt.xlabel('Market Cap')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(6)) #Display only part of horizontal ordinates. 6 is the Spacing distance
plt.xticks(rotation=-90)
plt.ylabel('Price')
#Scatter plot
# Out:
# Text(-12.555555555555555, 0.5, 'Price')

# %%
plt.plot(x['Date'],x['Market Cap'],label='Market Cap',color='b')
plt.xlabel('Date')
plt.title('Market Cap')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(6))
plt.xticks(rotation=-90)
plt.show()

plt.plot(x['Date'],x['AvePrice'],label='Price',color='green')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(6))
plt.xlabel('Date')
plt.title('Price')
plt.xticks(rotation=-90)
plt.show()

# %%
print(x.corr(),'\n')
import statsmodels.api as sm #Study the linear relationship between market cap and price
result=sm.OLS(x['Market Cap'],x['AvePrice']).fit()
print(result.summary())
# Out:
#             Market Cap  Volume  Open  Close  AvePrice
# Market Cap        1.00    0.38  1.00   0.93      0.98
# Volume            0.38    1.00  0.37   0.26      0.32
# Open              1.00    0.37  1.00   0.93      0.98
# Close             0.93    0.26  0.93   1.00      0.98
# AvePrice          0.98    0.32  0.98   0.98      1.00
#
#                                  OLS Regression Results
# ...
# Dep. Variable:             Market Cap   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          2.200e+05
# Date:                Fri, 16 Dec 2022   Prob (F-statistic):                   1.67e-105
# Time:                        02:40:01   Log-Likelihood:                         -1410.6
# No. Observations:                  59   AIC:                                      2823.
# ...

# %%
Y=pd.DataFrame() #Autoregression of stock price data. today and yesterday
Y['todayPrice']=x['AvePrice'][:58].reset_index(drop=True)
Y['yesterdayPrice']=x['AvePrice'][1:].reset_index(drop=True)
print(Y.info())
result=sm.OLS(Y['todayPrice'],Y['yesterdayPrice']).fit()
print(result.summary())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   todayPrice      58 non-null     float64
#  1   yesterdayPrice  58 non-null     float64
# dtypes: float64(2)
# memory usage: 1.0 KB
# None
#                                  OLS Regression Results
# ...
# Dep. Variable:             todayPrice   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          1.046e+05
# Date:                Fri, 16 Dec 2022   Prob (F-statistic):                    1.01e-94
# Time:                        02:40:15   Log-Likelihood:                         -435.00
# No. Observations:                  58   AIC:                                      872.0
# ...
